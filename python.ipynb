# %%
print("hola soy angie y estoy aprendiendo python para imagenes medicas con ia")
# Out:
# hola soy angie y estoy aprendiendo python para imagenes medicas con ia

# %%
frecuencia_cardiaca = 85
print(frecuencia_cardiaca)
# Out:
# 85

# %%
frecuencia_cardiaca =85
presion_sistolica = 120
presion_diastolica = 80

promedio_presion = (presion_sistolica+presion_diastolica) / 2

print("frecuencia cardiaca", frecuencia_cardiaca)
print("promedio presion arterial", promedio_presion)
# Out:
# frecuencia cardiaca 85
# promedio presion arterial 100.0

# %%
if frecuencia_cardiaca >100:
  print("alerta: posible taquicardia")
else:
  print("frecuencia normal")
# Out:
# frecuencia normal
